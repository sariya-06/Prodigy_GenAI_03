# %% [markdown]
# <a href="https://colab.research.google.com/github/sariya-06/Prodigy_GenAI_03/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install markovify

# %%
from google.colab import files
uploaded = files.upload()

# %%
import markovify

with open("sample.txt", "r", encoding="utf-8") as f:
    text_sample = f.read()

# %%
text_model = markovify.Text(text_sample, state_size=2)

# %%
for i in range(20):
  sentence = text_model.make_short_sentence(500)
  print(sentence)

# %%
from google.colab import files
uploaded = files.upload()

# %%
import markovify

with open("sample_1.txt", "r", encoding="utf-8") as f:
    text_sample_1= f.read()

# %%
import markovify

with open("sample_1.txt", "r", encoding="utf-8") as f:
    text_sample_1= f.read()

# %%
text_model = markovify.Text(text_sample_1, state_size=2)

# %%
for i in range(30):
  sentence = text_model.make_short_sentence(500)
  print(sentence)
